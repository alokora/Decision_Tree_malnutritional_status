# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
 
#importing Dataset
df = pd.read_csv('stunting.csv')
 
#Creating the heatmap
plt.figure(figsize = (8,6))
sb.heatmap(df.isnull(), cbar=False , cmap = 'magma')
# Out:
# <Axes: >

# %%
import pandas as pd
 
#importing dataset
df = pd.read_csv('stunting.csv')
 
df.isnull().sum()
# Out:
# ISO3Code                 0
# CountryName              0
# UNRegion                 0
# WB_Latest                0
# DataSourceYears          0
#                       ...
#  meduc_high             87
#  meduc_secondhigh       77
#  meduc_noneprimary      83
# newnum                 108
# mothers_edu            108
# Length: 62, dtype: int64

# %%
#imporing pandas
import pandas as pd
 
#Importing dataset
df = pd.read_csv('stunting.csv')
 
#Size of original dataset
print(df.shape)
 
#Dropping the missing rows.
# Out:
# (156, 62)

# %%
import pandas as pd
 
#importing the dataset
df = pd.read_csv('stunting.csv')

#df.drop('UNICEF_Survey_ID', inplace=True, axis=1)
#df.drop(' DataSourceTypeGlobal ', inplace=True, axis=1)
#df.drop(' FullSourceTitle ', inplace=True, axis=1)

  
df
# Out:
#     ISO3Code                         CountryName  \
# 0        AFG                         Afghanistan
# 1        ALB                             Albania
# 2        DZA                             Algeria
# 3        AGO                              Angola
# 4        ARG                           Argentina
# ..       ...                                 ...
# 151      VEN  Venezuela (Bolivarian Republic of)
# 152      VNM                            Viet Nam
# 153      YEM                               Yemen
# 154      ZMB                              Zambia
# 155      ZWE                            Zimbabwe
#
#                             UNRegion            WB_Latest DataSourceYears  \
# 0                               Asia           Low Income            2018
# 1                             Europe  Upper Middle Income         2017-18
# 2                             Africa  Lower Middle Income         2018-19
# 3                             Africa  Lower Middle Income         2015-16
# ...

# %%
df.columns
# Out:
# Index(['ISO3Code', 'CountryName', 'UNRegion', 'WB_Latest', 'DataSourceYears',
#        'CMRS_year', 'SourceW', ' rural_r ', ' rural_weighted_N ',
#        ' meduc_none_r ', ' meduc_none_weighted_N ', ' meduc_primary_r ',
#        ' meduc_primary_weighted_N ', ' meduc_noneprimary_r ',
#        ' meduc_noneprimary_weighted_N ', ' meduc_second_r ',
#        ' meduc_second_weighted_N ', ' meduc_high_r ',
#        ' meduc_high_weighted_N ', ' meduc_secondhigh_r ',
#        ' meduc_secondhigh_weighted_N ', ' male_month_0_5_r ',
#        ' male_month_0_5_weighted_N ', ' male_month_6_11_r ',
#        ' male_month_6_11_weighted_N ', ' male_month_12_23_r ',
#        ' male_month_12_23_weighted_N ', ' male_month_0_23_r ',
#        ' male_month_0_23_weighted_N ', ' male_month_24_35_r ',
#        ' male_month_24_35_weighted_N ', ' male_month_36_47_r ',
#        ' male_month_36_47_weighted_N ', ' male_month_48_59_r ',
#        ' male_month_48_59_weighted_N ', ' male_month_24_59_r ',
# ...

# %%
df_new=df[df['SourceW']=="Historical Trend"]
df_new
# Out:
# Empty DataFrame
# ...

# %%
df=df[df['SourceW']=="Latest Source"]
df
# Out:
#     ISO3Code                         CountryName  \
# 0        AFG                         Afghanistan
# 1        ALB                             Albania
# 2        DZA                             Algeria
# 3        AGO                              Angola
# 4        ARG                           Argentina
# ..       ...                                 ...
# 151      VEN  Venezuela (Bolivarian Republic of)
# 152      VNM                            Viet Nam
# 153      YEM                               Yemen
# 154      ZMB                              Zambia
# 155      ZWE                            Zimbabwe
#
#                             UNRegion            WB_Latest DataSourceYears  \
# 0                               Asia           Low Income            2018
# 1                             Europe  Upper Middle Income         2017-18
# 2                             Africa  Lower Middle Income         2018-19
# 3                             Africa  Lower Middle Income         2015-16
# ...

# %%
#df.drop('UNICEF_Reporting_Sub_Region', inplace=True, axis=1)
#df.drop('WHORegion', inplace=True, axis=1)
#df.drop(' Estimate_Type ', inplace=True, axis=1)
df
# Out:
#     ISO3Code                         CountryName  \
# 0        AFG                         Afghanistan
# 1        ALB                             Albania
# 2        DZA                             Algeria
# 3        AGO                              Angola
# 4        ARG                           Argentina
# ..       ...                                 ...
# 151      VEN  Venezuela (Bolivarian Republic of)
# 152      VNM                            Viet Nam
# 153      YEM                               Yemen
# 154      ZMB                              Zambia
# 155      ZWE                            Zimbabwe
#
#                             UNRegion            WB_Latest DataSourceYears  \
# 0                               Asia           Low Income            2018
# 1                             Europe  Upper Middle Income         2017-18
# 2                             Africa  Lower Middle Income         2018-19
# 3                             Africa  Lower Middle Income         2015-16
# ...

# %%
#df = df.loc[:, :' female_month_24_59_Footnote ']
df
# Out:
#     ISO3Code                         CountryName  \
# 0        AFG                         Afghanistan
# 1        ALB                             Albania
# 2        DZA                             Algeria
# 3        AGO                              Angola
# 4        ARG                           Argentina
# ..       ...                                 ...
# 151      VEN  Venezuela (Bolivarian Republic of)
# 152      VNM                            Viet Nam
# 153      YEM                               Yemen
# 154      ZMB                              Zambia
# 155      ZWE                            Zimbabwe
#
#                             UNRegion            WB_Latest DataSourceYears  \
# 0                               Asia           Low Income            2018
# 1                             Europe  Upper Middle Income         2017-18
# 2                             Africa  Lower Middle Income         2018-19
# 3                             Africa  Lower Middle Income         2015-16
# ...

# %%
x=df.columns.tolist()
x
# Out:
# ['ISO3Code',
#  'CountryName',
#  'UNRegion',
#  'WB_Latest',
#  'DataSourceYears',
#  'CMRS_year',
#  'SourceW',
#  ' rural_r ',
#  ' rural_weighted_N ',
#  ' meduc_none_r ',
#  ' meduc_none_weighted_N ',
#  ' meduc_primary_r ',
#  ' meduc_primary_weighted_N ',
#  ' meduc_noneprimary_r ',
#  ' meduc_noneprimary_weighted_N ',
#  ' meduc_second_r ',
#  ' meduc_second_weighted_N ',
#  ' meduc_high_r ',
#  ' meduc_high_weighted_N ',
#  ' meduc_secondhigh_r ',
#  ' meduc_secondhigh_weighted_N ',
#  ' male_month_0_5_r ',
#  ' male_month_0_5_weighted_N ',
#  ' male_month_6_11_r ',
#  ' male_month_6_11_weighted_N ',
#  ' male_month_12_23_r ',
#  ' male_month_12_23_weighted_N ',
#  ' male_month_0_23_r ',
#  ' male_month_0_23_weighted_N ',
#  ' male_month_24_35_r ',
#  ' male_month_24_35_weighted_N ',
#  ' male_month_36_47_r ',
#  ' male_month_36_47_weighted_N ',
#  ' male_month_48_59_r ',
#  ' male_month_48_59_weighted_N ',
#  ' male_month_24_59_r ',
#  ' male_month_24_59_weighted_N ',
# ...

# %%
plt.figure(figsize = (8,6))
sb.heatmap(df.isnull(), cbar=False , cmap = 'magma')
df.isnull().sum()
# Out:
# ISO3Code                 0
# CountryName              0
# UNRegion                 0
# WB_Latest                0
# DataSourceYears          0
#                       ...
#  meduc_high             87
#  meduc_secondhigh       77
#  meduc_noneprimary      83
# newnum                 108
# mothers_edu            108
# Length: 62, dtype: int64

# %%
#df.drop(' Q1_urban_r ', inplace=True, axis=1)
#df.drop(' Q1_urban_ll ', inplace=True, axis=1)
#df.drop(' Q1_urban_ul ', inplace=True, axis=1)
#df.drop(' Q1_urban_weighted_N ', inplace=True, axis=1)
#df.drop(' Q1_urban_Footnote ', inplace=True, axis=1)

# %%
#df.drop(' Q2_urban_r ', inplace=True, axis=1)
#df.drop(' Q2_urban_ll ', inplace=True, axis=1)
#df.drop(' Q2_urban_ul ', inplace=True, axis=1)
#df.drop(' Q2_urban_weighted_N ', inplace=True, axis=1)
#df.drop(' Q2_urban_Footnote ', inplace=True, axis=1)

# %%
""""df.drop(' Q3_urban_r ', inplace=True, axis=1)
df.drop(' Q3_urban_ll ', inplace=True, axis=1)
df.drop(' Q3_urban_ul ', inplace=True, axis=1)
df.drop(' Q3_urban_weighted_N ', inplace=True, axis=1)
df.drop(' Q3_urban_Footnote ', inplace=True, axis=1)
df.drop(' Q4_urban_r ', inplace=True, axis=1)
df.drop(' Q4_urban_ll ', inplace=True, axis=1)
df.drop(' Q4_urban_ul ', inplace=True, axis=1)
df.drop(' Q4_urban_weighted_N ', inplace=True, axis=1)
df.drop(' Q4_urban_Footnote ', inplace=True, axis=1)
df.drop(' Q5_urban_r ', inplace=True, axis=1)
df.drop(' Q5_urban_ll ', inplace=True, axis=1)
df.drop(' Q5_urban_ul ', inplace=True, axis=1)
df.drop(' Q5_urban_weighted_N ', inplace=True, axis=1)
df.drop(' Q5_urban_Footnote ', inplace=True, axis=1)
# Out:
#   File "/tmp/ipykernel_805/1759490332.py", line 1
#     """"df.drop(' Q3_urban_r ', inplace=True, axis=1)
#     ^
# SyntaxError: incomplete input

# %%
"""df.drop([' Bottom_20_urban_r ',' Bottom_20_urban_ll ',' Bottom_20_urban_ul ',' Bottom_20_urban_weighted_N ',' Bottom_20_urban_Footnote '], inplace=True, axis=1)
df.drop([' Bottom_40_urban_r ',' Bottom_40_urban_ll ',' Bottom_40_urban_ul ',' Bottom_40_urban_weighted_N ',' Bottom_40_urban_Footnote '], inplace=True, axis=1)
df.drop([' Bottom_60_urban_r ',' Bottom_60_urban_ll ',' Bottom_60_urban_ul ',' Bottom_60_urban_weighted_N ',' Bottom_60_urban_Footnote '], inplace=True, axis=1)
df.drop([' Bottom_80_urban_r ',' Bottom_80_urban_ll ',' Bottom_80_urban_ul ',' Bottom_80_urban_weighted_N ',' Bottom_80_urban_Footnote '], inplace=True, axis=1)

df.drop([' Top_20_urban_r ',' Top_20_urban_ll ',' Top_20_urban_ul ',' Top_20_urban_weighted_N ',' Top_20_urban_Footnote '], inplace=True, axis=1)
df.drop([' Top_40_urban_r ',' Top_40_urban_ll ',' Top_40_urban_ul ',' Top_40_urban_weighted_N ',' Top_40_urban_Footnote '], inplace=True, axis=1)
df.drop([' Top_60_urban_r ',' Top_60_urban_ll ',' Top_60_urban_ul ',' Top_60_urban_weighted_N ',' Top_60_urban_Footnote '], inplace=True, axis=1)
df.drop([' Top_80_urban_r ',' Top_80_urban_ll ',' Top_80_urban_ul ',' Top_80_urban_weighted_N ',' Top_80_urban_Footnote '], inplace=True, axis=1)
"""
# Out:
# "df.drop([' Bottom_20_urban_r ',' Bottom_20_urban_ll ',' Bottom_20_urban_ul ',' Bottom_20_urban_weighted_N ',' Bottom_20_urban_Footnote '], inplace=True, axis=1)\ndf.drop([' Bottom_40_urban_r ',' Bottom_40_urban_ll ',' Bottom_40_urban_ul ',' Bottom_40_urban_weighted_N ',' Bottom_40_urban_Footnote '], inplace=True, axis=1)\ndf.drop([' Bottom_60_urban_r ',' Bottom_60_urban_ll ',' Bottom_60_urban_ul ',' Bottom_60_urban_weighted_N ',' Bottom_60_urban_Footnote '], inplace=True, axis=1)\ndf.drop([' Bottom_80_urban_r ',' Bottom_80_urban_ll ',' Bottom_80_urban_ul ',' Bottom_80_urban_weighted_N ',' Bottom_80_urban_Footnote '], inplace=True, axis=1)\n\ndf.drop([' Top_20_urban_r ',' Top_20_urban_ll ',' Top_20_urban_ul ',' Top_20_urban_weighted_N ',' Top_20_urban_Footnote '], inplace=True, axis=1)\ndf.drop([' Top_40_urban_r ',' Top_40_urban_ll ',' Top_40_urban_ul ',' Top_40_urban_weighted_N ',' Top_40_urban_Footnote '], inplace=True, axis=1)\ndf.drop([' Top_60_urban_r ',' Top_60_urban_ll ',' Top
# ...

# %%
df
# Out:
#     ISO3Code                         CountryName  \
# 0        AFG                         Afghanistan
# 1        ALB                             Albania
# 2        DZA                             Algeria
# 3        AGO                              Angola
# 4        ARG                           Argentina
# ..       ...                                 ...
# 151      VEN  Venezuela (Bolivarian Republic of)
# 152      VNM                            Viet Nam
# 153      YEM                               Yemen
# 154      ZMB                              Zambia
# 155      ZWE                            Zimbabwe
#
#                             UNRegion            WB_Latest DataSourceYears  \
# 0                               Asia           Low Income            2018
# 1                             Europe  Upper Middle Income         2017-18
# 2                             Africa  Lower Middle Income         2018-19
# 3                             Africa  Lower Middle Income         2015-16
# ...

# %%
df.columns.tolist()
# Out:
# ['ISO3Code',
#  'CountryName',
#  'UNRegion',
#  'WB_Latest',
#  'DataSourceYears',
#  'CMRS_year',
#  'SourceW',
#  ' rural_r ',
#  ' rural_weighted_N ',
#  ' meduc_none_r ',
#  ' meduc_none_weighted_N ',
#  ' meduc_primary_r ',
#  ' meduc_primary_weighted_N ',
#  ' meduc_noneprimary_r ',
#  ' meduc_noneprimary_weighted_N ',
#  ' meduc_second_r ',
#  ' meduc_second_weighted_N ',
#  ' meduc_high_r ',
#  ' meduc_high_weighted_N ',
#  ' meduc_secondhigh_r ',
#  ' meduc_secondhigh_weighted_N ',
#  ' male_month_0_5_r ',
#  ' male_month_0_5_weighted_N ',
#  ' male_month_6_11_r ',
#  ' male_month_6_11_weighted_N ',
#  ' male_month_12_23_r ',
#  ' male_month_12_23_weighted_N ',
#  ' male_month_0_23_r ',
#  ' male_month_0_23_weighted_N ',
#  ' male_month_24_35_r ',
#  ' male_month_24_35_weighted_N ',
#  ' male_month_36_47_r ',
#  ' male_month_36_47_weighted_N ',
#  ' male_month_48_59_r ',
#  ' male_month_48_59_weighted_N ',
#  ' male_month_24_59_r ',
#  ' male_month_24_59_weighted_N ',
# ...

# %%
""""df.drop([' Bottom_20_r ',' Bottom_20_ll ',' Bottom_20_ul ',' Bottom_20_weighted_N ',' Bottom_20_Footnote '], inplace=True, axis=1)
df.drop([' Bottom_40_r ',' Bottom_40_ll ',' Bottom_40_ul ',' Bottom_40_weighted_N ',' Bottom_40_Footnote '], inplace=True, axis=1)
df.drop([' Bottom_60_r ',' Bottom_60_ll ',' Bottom_60_ul ',' Bottom_60_weighted_N ',' Bottom_60_Footnote '], inplace=True, axis=1)
df.drop([' Bottom_80_r ',' Bottom_80_ll ',' Bottom_80_ul ',' Bottom_80_weighted_N ',' Bottom_80_Footnote '], inplace=True, axis=1)

df.drop([' Top_20_r ',' Top_20_ll ',' Top_20_ul ',' Top_20_weighted_N ',' Top_20_Footnote '], inplace=True, axis=1)
df.drop([' Top_40_r ',' Top_40_ll ',' Top_40_ul ',' Top_40_weighted_N ',' Top_40_Footnote '], inplace=True, axis=1)
df.drop([' Top_60_r ',' Top_60_ll ',' Top_60_ul ',' Top_60_weighted_N ',' Top_60_Footnote '], inplace=True, axis=1)
df.drop([' Top_80_r ',' Top_80_ll ',' Top_80_ul ',' Top_80_weighted_N ',' Top_80_Footnote '], inplace=True, axis=1)

df.drop(' Q1_r ', inplace=True, axis=1)
df.drop(' Q1_ll ', inplace=True, axis=1)
df.drop(' Q1_ul ', inplace=True, axis=1)
df.drop(' Q1_weighted_N ', inplace=True, axis=1)
df.drop(' Q1_Footnote ', inplace=True, axis=1)

df.drop(' Q2_r ', inplace=True, axis=1)
df.drop(' Q2_ll ', inplace=True, axis=1)
df.drop(' Q2_ul ', inplace=True, axis=1)
df.drop(' Q2_weighted_N ', inplace=True, axis=1)
df.drop(' Q2_Footnote ', inplace=True, axis=1)

df.drop(' Q3_r ', inplace=True, axis=1)
df.drop(' Q3_ll ', inplace=True, axis=1)
df.drop(' Q3_ul ', inplace=True, axis=1)
df.drop(' Q3_weighted_N ', inplace=True, axis=1)
df.drop(' Q3_Footnote ', inplace=True, axis=1)

df.drop(' Q4_r ', inplace=True, axis=1)
df.drop(' Q4_ll ', inplace=True, axis=1)
df.drop(' Q4_ul ', inplace=True, axis=1)
df.drop(' Q4_weighted_N ', inplace=True, axis=1)
df.drop(' Q4_Footnote ', inplace=True, axis=1)

df.drop(' Q5_r ', inplace=True, axis=1)
df.drop(' Q5_ll ', inplace=True, axis=1)
df.drop(' Q5_ul ', inplace=True, axis=1)
df.drop(' Q5_weighted_N ', inplace=True, axis=1)
df.drop(' Q5_Footnote ', inplace=True, axis=1)
# Out:
#   File "/tmp/ipykernel_805/2561015426.py", line 1
#     """"df.drop([' Bottom_20_r ',' Bottom_20_ll ',' Bottom_20_ul ',' Bottom_20_weighted_N ',' Bottom_20_Footnote '], inplace=True, axis=1)
#     ^
# SyntaxError: incomplete input

# %%
df.shape
# Out:
# (156, 62)

# %%
plt.figure(figsize = (8,6))
sb.heatmap(df.isnull(), cbar=False , cmap = 'magma')
# Out:
# <Axes: >

# %%
df.to_csv('stunting.csv', index=False)
df.shape
# Out:
# (156, 62)

# %%
columns_to_remove = [col for col in df.columns if col.endswith('_ul ')]
df = df.drop(columns=columns_to_remove)
columns_to_remove = [col for col in df.columns if col.endswith('_ll ')]
df = df.drop(columns=columns_to_remove)

# %%
columns_to_remove = [col for col in df.columns if col.endswith('_Footnote ')]
df = df.drop(columns=columns_to_remove)
df = df[df.columns.drop(list(df.filter(regex='urban')))]
#df = df[df.columns.drop(list(df.filter(regex='weighted')))]
df = df[df.columns.drop(list(df.filter(regex='Q')))]
df = df[df.columns.drop(list(df.filter(regex='Top')))]
df = df[df.columns.drop(list(df.filter(regex='Bottom')))]
df = df[df.columns.drop(list(df.filter(regex='Footnote')))]

# %%
df.columns.tolist()
# Out:
# ['ISO3Code',
#  'CountryName',
#  'UNRegion',
#  'WB_Latest',
#  'DataSourceYears',
#  'CMRS_year',
#  'SourceW',
#  ' rural_r ',
#  ' rural_weighted_N ',
#  ' meduc_none_r ',
#  ' meduc_none_weighted_N ',
#  ' meduc_primary_r ',
#  ' meduc_primary_weighted_N ',
#  ' meduc_noneprimary_r ',
#  ' meduc_noneprimary_weighted_N ',
#  ' meduc_second_r ',
#  ' meduc_second_weighted_N ',
#  ' meduc_high_r ',
#  ' meduc_high_weighted_N ',
#  ' meduc_secondhigh_r ',
#  ' meduc_secondhigh_weighted_N ',
#  ' male_month_0_5_r ',
#  ' male_month_0_5_weighted_N ',
#  ' male_month_6_11_r ',
#  ' male_month_6_11_weighted_N ',
#  ' male_month_12_23_r ',
#  ' male_month_12_23_weighted_N ',
#  ' male_month_0_23_r ',
#  ' male_month_0_23_weighted_N ',
#  ' male_month_24_35_r ',
#  ' male_month_24_35_weighted_N ',
#  ' male_month_36_47_r ',
#  ' male_month_36_47_weighted_N ',
#  ' male_month_48_59_r ',
#  ' male_month_48_59_weighted_N ',
#  ' male_month_24_59_r ',
#  ' male_month_24_59_weighted_N ',
# ...

# %%
#numeric_columns = df.select_dtypes(include='number')

# Replace NaN values with column means

#df[numeric_columns.columns] = numeric_columns.fillna(numeric_columns.mean())

# %%
df.shape
# Out:
# (156, 62)

# %%
df.to_csv('stunting.csv', index=False)

# %%
plt.figure(figsize = (8,6))
sb.heatmap(df.isnull(), cbar=False , cmap = 'magma')
# Out:
# <Axes: >

# %%
df['newden']=df[' meduc_none_weighted_N ']+df[' meduc_primary_weighted_N ']+df[' meduc_second_weighted_N ']+df[' meduc_high_weighted_N ']+df[' meduc_secondhigh_weighted_N ']+df[' meduc_noneprimary_weighted_N ']

# %%
df[' meduc_none ']=df[' meduc_none_r ']*df[' meduc_none_weighted_N ']
df[' meduc_primary ']=df[' meduc_primary_r ']*df[' meduc_primary_weighted_N ']
df[' meduc_second ']=df[' meduc_second_r ']*df[' meduc_second_weighted_N ']
df[' meduc_high ']=df[' meduc_high_r ']*df[' meduc_high_weighted_N ']
df[' meduc_secondhigh ']=df[' meduc_secondhigh_r ']*df[' meduc_secondhigh_weighted_N ']
df[' meduc_noneprimary ']=df[' meduc_noneprimary_r ']*df[' meduc_noneprimary_weighted_N ']

# %%
df['newnum']=df[' meduc_none ']+df[' meduc_primary ']+df[' meduc_second ']+df[' meduc_high ']+df[' meduc_secondhigh ']+df[' meduc_noneprimary ']

# %%
df['mothers_edu']=df['newnum']/df['newden']

# %%
""""df.drop([' National_r ',' National_weighted_N ',' male_r ',' male_weighted_N ',' female_r ',' female_weighted_N '],inplace=True,axis=1)
df.drop([' month_0_5_r ',' month_0_5_weighted_N ',' month_6_11_r ',' month_6_11_weighted_N ',' month_12_23_r ',' month_12_23_weighted_N ',' month_0_23_r ',' month_0_23_weighted_N ',' month_24_35_r ',' month_24_35_weighted_N ',' month_36_47_r ',' month_36_47_weighted_N ',' month_48_59_r ',' month_48_59_weighted_N ',' month_24_59_r ',' month_24_59_weighted_N '],inplace=True,axis=1)"""
# Out:
# '"df.drop([\' National_r \',\' National_weighted_N \',\' male_r \',\' male_weighted_N \',\' female_r \',\' female_weighted_N \'],inplace=True,axis=1)\ndf.drop([\' month_0_5_r \',\' month_0_5_weighted_N \',\' month_6_11_r \',\' month_6_11_weighted_N \',\' month_12_23_r \',\' month_12_23_weighted_N \',\' month_0_23_r \',\' month_0_23_weighted_N \',\' month_24_35_r \',\' month_24_35_weighted_N \',\' month_36_47_r \',\' month_36_47_weighted_N \',\' month_48_59_r \',\' month_48_59_weighted_N \',\' month_24_59_r \',\' month_24_59_weighted_N \'],inplace=True,axis=1)'

# %%
df.to_csv('stunting.csv', index=False)
df.columns.tolist()
# Out:
# ['ISO3Code',
#  'CountryName',
#  'UNRegion',
#  'WB_Latest',
#  'DataSourceYears',
#  'CMRS_year',
#  'SourceW',
#  ' rural_r ',
#  ' rural_weighted_N ',
#  ' meduc_none_r ',
#  ' meduc_none_weighted_N ',
#  ' meduc_primary_r ',
#  ' meduc_primary_weighted_N ',
#  ' meduc_noneprimary_r ',
#  ' meduc_noneprimary_weighted_N ',
#  ' meduc_second_r ',
#  ' meduc_second_weighted_N ',
#  ' meduc_high_r ',
#  ' meduc_high_weighted_N ',
#  ' meduc_secondhigh_r ',
#  ' meduc_secondhigh_weighted_N ',
#  ' male_month_0_5_r ',
#  ' male_month_0_5_weighted_N ',
#  ' male_month_6_11_r ',
#  ' male_month_6_11_weighted_N ',
#  ' male_month_12_23_r ',
#  ' male_month_12_23_weighted_N ',
#  ' male_month_0_23_r ',
#  ' male_month_0_23_weighted_N ',
#  ' male_month_24_35_r ',
#  ' male_month_24_35_weighted_N ',
#  ' male_month_36_47_r ',
#  ' male_month_36_47_weighted_N ',
#  ' male_month_48_59_r ',
#  ' male_month_48_59_weighted_N ',
#  ' male_month_24_59_r ',
#  ' male_month_24_59_weighted_N ',
# ...

# %%
df1 = pd.melt(df, id_vars=['ISO3Code','CountryName','UNRegion','WB_Latest','DataSourceYears','CMRS_year','SourceW'], value_vars=[' male_month_0_5_r ',' male_month_6_11_r ',' male_month_12_23_r ',' male_month_0_23_r ',' male_month_24_35_r ',' male_month_36_47_r ',' male_month_48_59_r ',' male_month_24_59_r ',' female_month_0_5_r ',' female_month_6_11_r ',' female_month_12_23_r ',' female_month_0_23_r ',' female_month_24_35_r ',' female_month_36_47_r ',' female_month_48_59_r ',' female_month_24_59_r '], var_name='sex_age', value_name='stunting_r')

# %%
df1
# Out:
#      ISO3Code                         CountryName  \
# 0         AFG                         Afghanistan
# 1         ALB                             Albania
# 2         DZA                             Algeria
# 3         AGO                              Angola
# 4         ARG                           Argentina
# ...       ...                                 ...
# 2491      VEN  Venezuela (Bolivarian Republic of)
# 2492      VNM                            Viet Nam
# 2493      YEM                               Yemen
# 2494      ZMB                              Zambia
# 2495      ZWE                            Zimbabwe
#
#                              UNRegion            WB_Latest DataSourceYears  \
# 0                                Asia           Low Income            2018
# 1                              Europe  Upper Middle Income         2017-18
# 2                              Africa  Lower Middle Income         2018-19
# ...

# %%
df11 = pd.melt(df, id_vars=['ISO3Code','CountryName','UNRegion','WB_Latest','DataSourceYears','CMRS_year','SourceW'], value_vars=[' male_month_0_5_weighted_N ',' male_month_6_11_weighted_N ',' male_month_12_23_weighted_N ',' male_month_0_23_weighted_N ',' male_month_24_35_weighted_N ',' male_month_36_47_weighted_N ',' male_month_48_59_weighted_N ',' male_month_24_59_weighted_N ',' female_month_0_5_weighted_N ',' female_month_6_11_weighted_N ',' female_month_12_23_weighted_N ',' female_month_0_23_weighted_N ',' female_month_24_35_weighted_N ',' female_month_36_47_weighted_N ',' female_month_48_59_weighted_N ',' female_month_24_59_weighted_N '], var_name='sex_age', value_name='stunting_weighted')

# %%
df1['sex_age'] = df1['sex_age'].replace({' male_month_0_5_r ':
 ' male_month_0_5 ',
 ' male_month_6_11_r ':
 ' male_month_6_11 ',
 ' male_month_12_23_r ':
 ' male_month_12_23 ',
 ' male_month_0_23_r ':
 ' male_month_0_23 ',
 ' male_month_24_35_r ':
 ' male_month_24_35 ',
 ' male_month_36_47_r ':
 ' male_month_36_47 ',
 ' male_month_48_59_r ':
 ' male_month_48_59 ',
 ' male_month_24_59_r ':
 ' male_month_24_59 ',
 ' female_month_0_5_r ':
 ' female_month_0_5 ',
 ' female_month_6_11_r ':
 ' female_month_6_11 ',
 ' female_month_12_23_r ':
 ' female_month_12_23 ',
 ' female_month_0_23_r ':
 ' female_month_0_23 ',
 ' female_month_24_35_r ':
 ' female_month_24_35 ',
 ' female_month_36_47_r ':
 ' female_month_36_47 ',
 ' female_month_48_59_r ':
 ' female_month_48_59 ',
 ' female_month_24_59_r ':
 ' female_month_24_59 '})
                              
df11['sex_age'] = df11['sex_age'].replace({' male_month_0_5_weighted_N ':
 ' male_month_0_5 ',
 ' male_month_6_11_weighted_N ':
 ' male_month_6_11 ',
 ' male_month_12_23_weighted_N ':
 ' male_month_12_23 ',
 ' male_month_0_23_weighted_N ':
 ' male_month_0_23 ',
 ' male_month_24_35_weighted_N ':
 ' male_month_24_35 ',
 ' male_month_36_47_weighted_N ':
 ' male_month_36_47 ',
 ' male_month_48_59_weighted_N ':
 ' male_month_48_59 ',
 ' male_month_24_59_weighted_N':
 ' male_month_24_59 ',
 ' female_month_0_5_weighted_N ':
 ' female_month_0_5 ',
 ' female_month_6_11_weighted_N ':
 ' female_month_6_11 ',
 ' female_month_12_23_weighted_N ':
 ' female_month_12_23 ',
 ' female_month_0_23_weighted_N ':
 ' female_month_0_23 ',
 ' female_month_24_35_weighted_N ':
 ' female_month_24_35 ',
 ' female_month_36_47_weighted_N ':
 ' female_month_36_47 ',
 ' female_month_48_59_weighted_N ':
 ' female_month_48_59 ',
 ' female_month_24_59_weighted_N ':
 ' female_month_24_59 '})

# %%
df11
# Out:
#      ISO3Code                         CountryName  \
# 0         AFG                         Afghanistan
# 1         ALB                             Albania
# 2         DZA                             Algeria
# 3         AGO                              Angola
# 4         ARG                           Argentina
# ...       ...                                 ...
# 2491      VEN  Venezuela (Bolivarian Republic of)
# 2492      VNM                            Viet Nam
# 2493      YEM                               Yemen
# 2494      ZMB                              Zambia
# 2495      ZWE                            Zimbabwe
#
#                              UNRegion            WB_Latest DataSourceYears  \
# 0                                Asia           Low Income            2018
# 1                              Europe  Upper Middle Income         2017-18
# 2                              Africa  Lower Middle Income         2018-19
# ...

# %%
df1 = pd.merge(df1, df11, on=['ISO3Code',
 'CountryName',
 'UNRegion',
 'WB_Latest',
 'DataSourceYears',
 'CMRS_year',
 'SourceW','sex_age'], how='inner')
df1
# Out:
#      ISO3Code                         CountryName  \
# 0         AFG                         Afghanistan
# 1         ALB                             Albania
# 2         DZA                             Algeria
# 3         AGO                              Angola
# 4         ARG                           Argentina
# ...       ...                                 ...
# 2335      VEN  Venezuela (Bolivarian Republic of)
# 2336      VNM                            Viet Nam
# 2337      YEM                               Yemen
# 2338      ZMB                              Zambia
# 2339      ZWE                            Zimbabwe
#
#                              UNRegion            WB_Latest DataSourceYears  \
# 0                                Asia           Low Income            2018
# 1                              Europe  Upper Middle Income         2017-18
# 2                              Africa  Lower Middle Income         2018-19
# ...

# %%
df2 = pd.melt(df, id_vars=['ISO3Code','CountryName','UNRegion','WB_Latest','DataSourceYears','CMRS_year','SourceW'], value_vars=[' meduc_none_r ',

 ' meduc_primary_r ',

 ' meduc_noneprimary_r ',
 
 ' meduc_second_r ',

 ' meduc_high_r ',

 ' meduc_secondhigh_r '], var_name='mothers_education', value_name='stunting_r')
df22 = pd.melt(df, id_vars=['ISO3Code','CountryName','UNRegion','WB_Latest','DataSourceYears','CMRS_year','SourceW'], value_vars=[
 ' meduc_none_weighted_N ',

 ' meduc_primary_weighted_N ',

 ' meduc_noneprimary_weighted_N ',

 ' meduc_second_weighted_N ',

 ' meduc_high_weighted_N ',
 
 ' meduc_secondhigh_weighted_N '], var_name='mothers_education', value_name='stuntingt_weighted')

df2['mothers_education'] = df2['mothers_education'].replace({' meduc_none_r ':'none',

 ' meduc_primary_r ':'primary',

 ' meduc_noneprimary_r ':'none-primary',
 
 ' meduc_second_r ':'secondary',

 ' meduc_high_r ':'higher',

 ' meduc_secondhigh_r ':'higher_secondary'})
                              
df22['mothers_education'] = df22['mothers_education'].replace({' meduc_none_weighted_N ':'none',

 ' meduc_primary_weighted_N ':'primary',

 ' meduc_noneprimary_weighted_N ':'none-primary',

 ' meduc_second_weighted_N ':'secondary',

 ' meduc_high_weighted_N ':'higher',
 
 ' meduc_secondhigh_weighted_N ':'higher_secondary'})

# %%
df2
# Out:
#     ISO3Code                         CountryName  \
# 0        AFG                         Afghanistan
# 1        ALB                             Albania
# 2        DZA                             Algeria
# 3        AGO                              Angola
# 4        ARG                           Argentina
# ..       ...                                 ...
# 931      VEN  Venezuela (Bolivarian Republic of)
# 932      VNM                            Viet Nam
# 933      YEM                               Yemen
# 934      ZMB                              Zambia
# 935      ZWE                            Zimbabwe
#
#                             UNRegion            WB_Latest DataSourceYears  \
# 0                               Asia           Low Income            2018
# 1                             Europe  Upper Middle Income         2017-18
# 2                             Africa  Lower Middle Income         2018-19
# 3                             Africa  Lower Middle Income         2015-16
# ...

# %%
df2 = pd.merge(df2, df22, on=['ISO3Code',
 'CountryName',
 'UNRegion',
 'WB_Latest',
 'DataSourceYears',
 'CMRS_year',
 'SourceW','mothers_education'], how='inner')
df2
# Out:
#     ISO3Code                         CountryName  \
# 0        AFG                         Afghanistan
# 1        ALB                             Albania
# 2        DZA                             Algeria
# 3        AGO                              Angola
# 4        ARG                           Argentina
# ..       ...                                 ...
# 931      VEN  Venezuela (Bolivarian Republic of)
# 932      VNM                            Viet Nam
# 933      YEM                               Yemen
# 934      ZMB                              Zambia
# 935      ZWE                            Zimbabwe
#
#                             UNRegion            WB_Latest DataSourceYears  \
# 0                               Asia           Low Income            2018
# 1                             Europe  Upper Middle Income         2017-18
# 2                             Africa  Lower Middle Income         2018-19
# 3                             Africa  Lower Middle Income         2015-16
# ...

# %%
df3= df.loc[:, :' rural_weighted_N ']
df3.rename(columns={' rural_r ': 'rural_stunting_r'}, inplace=True)
df3.rename(columns={' rural_weighted_N ': 'rural_stunting_weighted'}, inplace=True)
df3
# Out:
#     ISO3Code                         CountryName  \
# 0        AFG                         Afghanistan
# 1        ALB                             Albania
# 2        DZA                             Algeria
# 3        AGO                              Angola
# 4        ARG                           Argentina
# ..       ...                                 ...
# 151      VEN  Venezuela (Bolivarian Republic of)
# 152      VNM                            Viet Nam
# 153      YEM                               Yemen
# 154      ZMB                              Zambia
# 155      ZWE                            Zimbabwe
#
#                             UNRegion            WB_Latest DataSourceYears  \
# 0                               Asia           Low Income            2018
# 1                             Europe  Upper Middle Income         2017-18
# 2                             Africa  Lower Middle Income         2018-19
# 3                             Africa  Lower Middle Income         2015-16
# ...

# %%
df1.columns.tolist()
# Out:
# ['ISO3Code',
#  'CountryName',
#  'UNRegion',
#  'WB_Latest',
#  'DataSourceYears',
#  'CMRS_year',
#  'SourceW',
#  'sex_age',
#  'stunting_r',
#  'stunting_weighted']

# %%
df1[['sex', 'age']] = df1['sex_age'].str.split('_',n=1, expand=True)

# %%
df.to_csv('stunting.csv', index=False)
df1.to_csv('stunting1.csv', index=False)
df2.to_csv('stunting2.csv', index=False)
df3.to_csv('stunting3.csv', index=False)
plt.figure(figsize = (8,6))
sb.heatmap(df1.isnull(), cbar=False , cmap = 'magma')
plt.figure(figsize = (8,6))
sb.heatmap(df2.isnull(), cbar=False , cmap = 'magma')
plt.figure(figsize = (8,6))
sb.heatmap(df3.isnull(), cbar=False , cmap = 'magma')
# Out:
# <Axes: >

# %%
df1
# Out:
#      ISO3Code                         CountryName  \
# 0         AFG                         Afghanistan
# 1         ALB                             Albania
# 2         DZA                             Algeria
# 3         AGO                              Angola
# 4         ARG                           Argentina
# ...       ...                                 ...
# 2335      VEN  Venezuela (Bolivarian Republic of)
# 2336      VNM                            Viet Nam
# 2337      YEM                               Yemen
# 2338      ZMB                              Zambia
# 2339      ZWE                            Zimbabwe
#
#                              UNRegion            WB_Latest DataSourceYears  \
# 0                                Asia           Low Income            2018
# 1                              Europe  Upper Middle Income         2017-18
# 2                              Africa  Lower Middle Income         2018-19
# ...

# %%
df2
# Out:
#     ISO3Code                         CountryName  \
# 0        AFG                         Afghanistan
# 1        ALB                             Albania
# 2        DZA                             Algeria
# 3        AGO                              Angola
# 4        ARG                           Argentina
# ..       ...                                 ...
# 931      VEN  Venezuela (Bolivarian Republic of)
# 932      VNM                            Viet Nam
# 933      YEM                               Yemen
# 934      ZMB                              Zambia
# 935      ZWE                            Zimbabwe
#
#                             UNRegion            WB_Latest DataSourceYears  \
# 0                               Asia           Low Income            2018
# 1                             Europe  Upper Middle Income         2017-18
# 2                             Africa  Lower Middle Income         2018-19
# 3                             Africa  Lower Middle Income         2015-16
# ...

# %%
df3
# Out:
#     ISO3Code                         CountryName  \
# 0        AFG                         Afghanistan
# 1        ALB                             Albania
# 2        DZA                             Algeria
# 3        AGO                              Angola
# 4        ARG                           Argentina
# ..       ...                                 ...
# 151      VEN  Venezuela (Bolivarian Republic of)
# 152      VNM                            Viet Nam
# 153      YEM                               Yemen
# 154      ZMB                              Zambia
# 155      ZWE                            Zimbabwe
#
#                             UNRegion            WB_Latest DataSourceYears  \
# 0                               Asia           Low Income            2018
# 1                             Europe  Upper Middle Income         2017-18
# 2                             Africa  Lower Middle Income         2018-19
# 3                             Africa  Lower Middle Income         2015-16
# ...
